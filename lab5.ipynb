# %% [markdown]
# # Sinh Viên thực hiện Lab 5 ở Đây

# %% [markdown]
# ## Lab 5 - Bài 1

# %%
class sanpham:
    def __init__(self,ten_san_pham,gia,giam_gia):
        self.ten_san_pham = ten_san_pham
        self.gia = gia
        self._giam_gia = giam_gia

# %% [markdown]
# ## Lab 5 - Bài 2

# %%
from sanpham import *

sp1 = sanpham("","","")
sp2 = sanpham("","","")
sp1.nhap_thong_tin_san_pham()
sp1.xuat_thong_tin_san_pham()
sp2.nhap_thong_tin_san_pham()
sp2.xuat_thong_tin_san_pham()
# Out:
# san pham: com co gia: 45000.0 duoc giam gia:10000.0 thue nhap khau: 4500.0
# san pham: bun co gia: 30000.0 duoc giam gia:2000.0 thue nhap khau: 3000.0

# %% [markdown]
# ## Lab 5 - Bài 3

# %%
# Code lab 5  bài 3 ở đây
from sanpham import SanPham3

sq1 = SanPham3()
sq2 = SanPham3()

print("Nhập thông tin sản phẩm 1: ")
sq1.nhap()
print("\nNhập thông tin sản phẩm 2: ")
sq2.nhap()

sq1.xuat()
sq2.xuat()

print("Tên sản phẩm 1: ", sq1.get_ten_san_pham())
print("Tên sản phẩm 2: ", sq2.get_ten_san_pham())
# Out:
# Nhập thông tin sản phẩm 1:
#
# Nhập thông tin sản phẩm 2:
# Tên sản phẩm: hi
# Đơn giá: 2,000 VND
# Giảm giá: 5,000 VND
# Thuế nhập khẩu: 200 VND
# ...
# Tên sản phẩm: hip
# Đơn giá: 5,000 VND
# Giảm giá: 1,000 VND
# Thuế nhập khẩu: 500 VND
# ...
# Tên sản phẩm 1:  hi
# Tên sản phẩm 2:  hip

# %% [markdown]
# ## Lab 5 - Bài 4

# %%
# code lab 5 bài 4 ở đây
from sanpham import SanPham4

print("Nhập thông tin sản phẩm 1: ")
ten1 = input("Tên sản phẩm: ")
gia1 = float(input("Giá: "))
giam1 = float(input("Giảm giá: "))

print("Nhập thông tin sản phẩm 2: ")
ten2 = input("Tên sản phẩm: ")
gia2 = float(input("Giá: "))
giam2 = float(input("Giảm giá: "))

sq1 = SanPham4(ten1, gia1, giam1)
sq2 = SanPham4(ten2, gia2, giam2)

sq1.xuat()
sq2.xuat()
# Out:
# Nhập thông tin sản phẩm 1:
# Nhập thông tin sản phẩm 2:
# Tên sản phẩm: fghjk
# Giá: 10000.0
# Giảm giá: 2000.0
# Giá sau giảm: 8000.0
# ------------------------------
# Tên sản phẩm: yuiop
# Giá: 20000.0
# Giảm giá: 10000.0
# Giá sau giảm: 10000.0
# ------------------------------

# %% [markdown]
# ## Lab 5 - Bài 5: bài tập làm thêm

# %%
# code lab 5  bài làm thêm ở đây
