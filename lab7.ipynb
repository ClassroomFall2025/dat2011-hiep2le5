# %% [markdown]
# # Sinh Viên thực hiện Lab 7 ở Đây

# %% [markdown]
# ## Lab 7 - Bài 1

# %%
with open("D:\DAT2011\dat2011-hiep2le5\Resource_1", "r", encoding="utf-8") as f:
        data = f.read()
        print(data)
import os

file_path = "D:\DAT2011\dat2011-hiep2le5\Resource_1"

if os.path.exists(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        content = f.read()
        print("Toàn bộ nội dung file:\n")
        print(content)

    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
        poem_name = lines[0][:9]
        print("\n Tên bài thơ:", poem_name)

        if len(lines) > 1:
            author = lines[1].strip()
            print("  Tác giả:", author)
        else:
            print("  Không tìm thấy dòng thứ hai trong file.")

else:
    print(" Không tìm thấy file! Hãy kiểm tra lại đường dẫn hoặc tên file.")
# Out:
# Tự nguyện
# Trương Quốc Khánh
# Nếu là chim, tôi sẽ là loài bồ câu trắng
# Nếu là hoa, tôi sẽ là một đóa hướng dương
# Nếu là mây, tôi sẽ là một vầng mây ấm
# Là người, tôi sẽ chết cho quê hương.
#
# Là chim, tôi sẽ cất cao đôi cánh mềm
# Từ nam ra ngoài bắc báo tin nối liền
# Là hoa, tôi nở tình yêu ban sớm
# Cùng muôn trái tim ngất ngây hoà bình.
#
# Là mây, theo làn gió tung bay khắp trời
# Nghìn xưa oai hùng đó tôi xin tiếp lời
# Là người, xin một lần khi nằm xuống
# Nhìn anh em đứng lên phất cao ngọn cờ.
# Toàn bộ nội dung file:
#
# Tự nguyện
# Trương Quốc Khánh
# Nếu là chim, tôi sẽ là loài bồ câu trắng
# Nếu là hoa, tôi sẽ là một đóa hướng dương
# Nếu là mây, tôi sẽ là một vầng mây ấm
# Là người, tôi sẽ chết cho quê hương.
#
# Là chim, tôi sẽ cất cao đôi cánh mềm
# Từ nam ra ngoài bắc báo tin nối liền
# Là hoa, tôi nở tình yêu ban sớm
# Cùng muôn trái tim ngất ngây hoà bình.
#
# Là mây, theo làn gió tung bay khắp trời
# Nghìn xưa oai hùng đó tôi xin tiếp lời
# Là người, xin một lần khi nằm xuống
# Nhìn anh em đứng lên phất cao ngọn cờ.
#
#  Tên bài thơ: Tự nguyện
#   Tác giả: Trương Quốc Khánh
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Thanh\AppData\Local\Temp\ipykernel_11360\2362251445.py:1: SyntaxWarning: invalid escape sequence '\D'
#   with open("D:\DAT2011\dat2011-hiep2le5\Resource_1", "r", encoding="utf-8") as f:
# C:\Users\Thanh\AppData\Local\Temp\ipykernel_11360\2362251445.py:6: SyntaxWarning: invalid escape sequence '\D'
#   file_path = "D:\DAT2011\dat2011-hiep2le5\Resource_1"

# %% [markdown]
# ## Lab 7 - Bài 2

# %%
file = open("Lab7-Exercise2.txt", "r", encoding="utf-8")
content = file.read()
print("\nNội dung file Lab7-Exercise2.txt:\n")
# Out:
# Nội dung file Lab7-Exercise2.txt:

# %% [markdown]
# ## Lab 7 - Bài 3

# %%
# Code lab 7  bài 3 ở đây

# %% [markdown]
# ## Lab 7 - Bài 4

# %%
# code lab 7 bài 4 ở đây

# %% [markdown]
# ## Lab 7 - Bài 5: bài tập làm thêm

# %%
# code lab 7  bài làm thêm ở đây
